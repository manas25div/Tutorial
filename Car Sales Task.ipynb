# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cars = pd.read_csv(r'C:\Users\MANAS\Desktop\Mission DS\Workshop\Cars task.csv')

# %%
cars
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2
# 0         NaN    Company       Freq
# 1         0.0       Audi        124
# 2         1.0        BMW         98
# 3         2.0   Mercedes        113
# 4         NaN      Total        335

# %%
x = ["Audi","BMW","Mercedes"]
y = [124,98,113]
c = ["red","yellow","blue"]

plt.bar(x,y,width=0.7,color = c)  # Bar chart
plt.xlabel ("Company")
plt.ylabel ("Frequency")
plt.title("Cars Sales Graph")
plt.show()

# %%
plt.pie(y, labels = x, radius = 1.2, shadow = True, autopct = ' %0.0f%% ')  # Pie chart
plt.show()

# %%
# Line chart
plt.plot(x,y)
plt.show()
