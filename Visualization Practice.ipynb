# %%
import pandas as pd
df = pd.read_csv (r'E:\College of Engineering,QU\SubPackage4644.6\movie.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2808/1235253792.py in <module>
#       1 import pandas as pd
# ----> 2 df = pd.read_csv (r'E:\College of Engineering,QU\SubPackage4644.6\movie.csv')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 27273   131254        Kein Bund für's Leben (2007)
# 27274   131256       Feuer, Eis & Dosenbier (2002)
# 27275   131258                  The Pirates (2014)
# 27276   131260                 Rentun Ruusu (2001)
# 27277   131262                    Innocence (2014)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...

# %% [markdown]
# stats

# %%
stats
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 27273   131254        Kein Bund für's Leben (2007)
# 27274   131256       Feuer, Eis & Dosenbier (2002)
# 27275   131258                  The Pirates (2014)
# 27276   131260                 Rentun Ruusu (2001)
# 27277   131262                    Innocence (2014)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...

# %%
len(stats)
# Out:
# 27278

# %%
stats.shape #
# Out:
# (27278, 3)

# %%
stats.columns #see columns
# Out:
# Index(['movieId', 'title', 'genres'], dtype='object')

# %%
len(stats.columns) #Number of columns
# Out:
# 3

# %%
stats.shape # No. of rows and columns
# Out:
# (27278, 3)

# %%
stats.head() #top 5 rows
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
stats.tail() # Bottom 5 rows
# Out:
#        movieId                          title                    genres
# 27273   131254   Kein Bund für's Leben (2007)                    Comedy
# 27274   131256  Feuer, Eis & Dosenbier (2002)                    Comedy
# 27275   131258             The Pirates (2014)                 Adventure
# 27276   131260            Rentun Ruusu (2001)        (no genres listed)
# 27277   131262               Innocence (2014)  Adventure|Fantasy|Horror

# %%
stats.tail(10)
# Out:
#        movieId                                              title  \
# 27268   131241                           Ants in the Pants (2000)
# 27269   131243                Werner - Gekotzt wird später (2003)
# 27270   131248                              Brother Bear 2 (2006)
# 27271   131250                              No More School (2000)
# 27272   131252  Forklift Driver Klaus: The First Day on the Jo...
# 27273   131254                       Kein Bund für's Leben (2007)
# 27274   131256                      Feuer, Eis & Dosenbier (2002)
# 27275   131258                                 The Pirates (2014)
# 27276   131260                                Rentun Ruusu (2001)
# 27277   131262                                   Innocence (2014)
#
#                                             genres
# 27268                               Comedy|Romance
# 27269                             Animation|Comedy
# 27270  Adventure|Animation|Children|Comedy|Fantasy
# ...

# %%
stats.info() # information of the column , strings are called as objects
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27278 entries, 0 to 27277
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  27278 non-null  int64
#  1   title    27278 non-null  object
#  2   genres   27278 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 639.5+ KB

# %%
stats.describe() #descriptive stats , Give Only Numerical information
# Out:
#              movieId
# count   27278.000000
# mean    59855.480570
# std     44429.314697
# min         1.000000
# 25%      6931.250000
# 50%     68068.000000
# 75%    100293.250000
# max    131262.000000

# %%
stats.describe().transpose() # transpose convert column into rows
# Out:
#            count         mean           std  min      25%      50%        75%  \
# movieId  27278.0  59855.48057  44429.314697  1.0  6931.25  68068.0  100293.25
#
#               max
# movieId  131262.0

# %%
stats.head(2) # Renaming columns of a dataframe
# Out:
#    movieId             title                                       genres
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        2    Jumanji (1995)                   Adventure|Children|Fantasy

# %%
stats.columns
# Out:
# Index(['movieId', 'title', 'genres'], dtype='object')

# %%
stats[:] # it will show entire dataframe
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 27273   131254        Kein Bund für's Leben (2007)
# 27274   131256       Feuer, Eis & Dosenbier (2002)
# 27275   131258                  The Pirates (2014)
# 27276   131260                 Rentun Ruusu (2001)
# 27277   131262                    Innocence (2014)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...

# %%
stats[:10]
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# 5                        Action|Crime|Thriller
# 6                               Comedy|Romance
# 7                           Adventure|Children
# ...

# %%
stats.head(10)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# 5                        Action|Crime|Thriller
# 6                               Comedy|Romance
# 7                           Adventure|Children
# ...

# %%
stats[::-1] # reverse the dataframe
# Out:
#        movieId                               title  \
# 27277   131262                    Innocence (2014)
# 27276   131260                 Rentun Ruusu (2001)
# 27275   131258                  The Pirates (2014)
# 27274   131256       Feuer, Eis & Dosenbier (2002)
# 27273   131254        Kein Bund für's Leben (2007)
# ...        ...                                 ...
# 4            5  Father of the Bride Part II (1995)
# 3            4            Waiting to Exhale (1995)
# 2            3             Grumpier Old Men (1995)
# 1            2                      Jumanji (1995)
# 0            1                    Toy Story (1995)
#
#                                             genres
# 27277                     Adventure|Fantasy|Horror
# 27276                           (no genres listed)
# 27275                                    Adventure
# 27274                                       Comedy
# 27273                                       Comedy
# ...

# %%
stats [: : 25]  # get only every 25th row
# Out:
#        movieId                                       title  \
# 0            1                            Toy Story (1995)
# 25          26                              Othello (1995)
# 50          51                       Guardian Angel (1994)
# 75          76                            Screamers (1995)
# 100        102                            Mr. Wrong (1996)
# ...        ...                                         ...
# 27175   130900                        Mr. Troop Mom (2009)
# 27200   131031        La liga no es cosa de hombres (1972)
# 27225   131100                        Forget me not (2013)
# 27250   131150  7 Dwarves: The Forest Is Not Enough (2006)
# 27275   131258                          The Pirates (2014)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 25                                           Drama
# 50                           Action|Drama|Thriller
# ...

# %%
stats['title']
# Out:
# 0                          Toy Story (1995)
# 1                            Jumanji (1995)
# 2                   Grumpier Old Men (1995)
# 3                  Waiting to Exhale (1995)
# 4        Father of the Bride Part II (1995)
#                         ...
# 27273          Kein Bund für's Leben (2007)
# 27274         Feuer, Eis & Dosenbier (2002)
# 27275                    The Pirates (2014)
# 27276                   Rentun Ruusu (2001)
# 27277                      Innocence (2014)
# Name: title, Length: 27278, dtype: object

# %%
stats['title'].head()
# Out:
# 0                      Toy Story (1995)
# 1                        Jumanji (1995)
# 2               Grumpier Old Men (1995)
# 3              Waiting to Exhale (1995)
# 4    Father of the Bride Part II (1995)
# Name: title, dtype: object

# %%
stats[4:8][['title','genres']]
# Out:
#                                 title                 genres
# 4  Father of the Bride Part II (1995)                 Comedy
# 5                         Heat (1995)  Action|Crime|Thriller
# 6                      Sabrina (1995)         Comedy|Romance
# 7                 Tom and Huck (1995)     Adventure|Children

# %%
stats[['title','genres']][4:8]
# Out:
#                                 title                 genres
# 4  Father of the Bride Part II (1995)                 Comedy
# 5                         Heat (1995)  Action|Crime|Thriller
# 6                      Sabrina (1995)         Comedy|Romance
# 7                 Tom and Huck (1995)     Adventure|Children

# %%
# Seaborn is very powerful STATISTIC VISUALIZATION package in Python
import matplotlib.pyplot as plt #visualization
import seaborn as sns # distribution visualization
#seaborn are used for advanced visualization e.x. --> distribution plot, line plot

# %matplotlib inline
plt.rcParams['figure.figsize'] = 10,5

import warnings
warnings.filterwarnings('ignore')  # OS error

# %%
stats.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
# Distributions :
vis1 = sns.distplot(stats["movieId"])  # UNIVARIATE ANALYSIS - statistics

# %%
vis1 = sns.distplot(stats["movieId"], bins=20)

# %%
# BOX PLOTS :
vis2 = sns.boxplot(data = stats, x = "movieId", y = 'title' )  # BI-VARIATE ANALYSIS

# %%
# refer to seaborn gallary

# %%
# visualizing with seaborn

# %%
vis3 = sns.lmplot(data = stats, x = 'moviedI', y = 'title', fit_reg = False) # lm - linear model

# %%
vis31 = sns.lmplot(data = stats, x = 'movieId', y = 'title', fit_reg = True)

# %%
vis4 = sns.lmplot(data = stats, x = 'movieId', y = 'title')
